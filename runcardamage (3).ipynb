# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="px27BVh7RFhdImkB7CnC")
project = rf.workspace("car-damage-kadad").project("car-damage-images")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Car-Damage-Images-3 in yolov11:: 100%|██████████| 612/612 [00:00<00:00, 9643.06it/s]

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 20.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="/content/Car-Damage-Images-3/data.yaml",  # path to dataset YAML
    epochs=20,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train3/weights/best.pt")

# Perform object detection on an image
results = model("/content/Car-Damage-Images-3/test/images", save=True)
results[0].show()
# Out:
# image 1/30 /content/Car-Damage-Images-3/test/images/0019_JPEG.rf.8f6151c03872a14cef97f7c051cc815c.jpg: 448x640 (no detections), 11.3ms
# image 2/30 /content/Car-Damage-Images-3/test/images/0069_JPEG.rf.ee8803672f54b003f766ffd7915eb87c.jpg: 448x640 (no detections), 8.4ms
# image 3/30 /content/Car-Damage-Images-3/test/images/0078_JPEG.rf.5837ccf0a3db0076a8dcd1ec35332478.jpg: 384x640 (no detections), 44.7ms
# image 4/30 /content/Car-Damage-Images-3/test/images/0110_JPEG.rf.c2e75d115e880610e33b252b03d3f322.jpg: 640x480 (no detections), 44.9ms
# image 5/30 /content/Car-Damage-Images-3/test/images/0157_jpeg.rf.8f8c41baacb42803aed839da8e40daa8.jpg: 480x640 1 front-end-damage, 1 rear-end-damage, 46.8ms
# image 6/30 /content/Car-Damage-Images-3/test/images/0160_JPEG.rf.76a0834e5ca8bbef0e1abd529c127f7f.jpg: 640x352 1 front-end-damage, 65.0ms
# image 7/30 /content/Car-Damage-Images-3/test/images/0171_JPEG.rf.e28a616da1461185cf0c345e0a0a58c9.jpg: 448x640 1 front-end-damage, 10.1ms
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model("/content/testcardamagge/hi.mp4", save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/888) /content/testcardamagge/hi.mp4: 384x640 (no detections), 106.5ms
# video 1/1 (frame 2/888) /content/testcardamagge/hi.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (frame 3/888) /content/testcardamagge/hi.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 4/888) /content/testcardamagge/hi.mp4: 384x640 (no detections), 8.7ms
# ...

# %%
13

# !zip -r /content/content.zip /content/Car-Damage-Images-3
# Out:
#   adding: content/Car-Damage-Images-3/ (stored 0%)
#   adding: content/Car-Damage-Images-3/valid/ (stored 0%)
#   adding: content/Car-Damage-Images-3/valid/images/ (stored 0%)
#   adding: content/Car-Damage-Images-3/valid/images/0219_JPEG.rf.c70a5335e8d0654ad40a3238de8dafcf.jpg (deflated 3%)
#   adding: content/Car-Damage-Images-3/valid/images/0268_JPEG.rf.546e559fe51b5ae1bd38b2b1b10fd238.jpg (deflated 3%)
#   adding: content/Car-Damage-Images-3/valid/images/0054_JPEG.rf.e8ad78ee72c6e16b3bd9a4856e82d9c6.jpg (deflated 3%)
#   adding: content/Car-Damage-Images-3/valid/images/0262_JPEG.rf.8172f25542efc4e9232d8f29b0f1f6b1.jpg (deflated 2%)
#   adding: content/Car-Damage-Images-3/valid/images/0710_jpeg.rf.7d24e3f995a00694b02cb674bbd6cceb.jpg (deflated 2%)
#   adding: content/Car-Damage-Images-3/valid/images/0370_JPEG.rf.7fd3d449e3b005e5787132752c72d3c4.jpg (deflated 2%)
#   adding: content/Car-Damage-Images-3/valid/images/0536_JPEG.rf.872fa89bce5712db6a3513fd3405859a.jpg (deflated 4%)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="px27BVh7RFhdImkB7CnC")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License-Plate-Recognition-4 in yolov11:: 100%|██████████| 48488/48488 [00:13<00:00, 3665.89it/s]

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="/content/License-Plate-Recognition-4/data.yaml",  # path to dataset YAML
    epochs=5,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train2/weights/best.pt")

# Perform object detection on an image
results = model("/content/test/0.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/test/0.jpg: 448x640 1 License_Plate, 44.6ms
# Speed: 14.2ms preprocess, 44.6ms inference, 920.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict6
# <PIL.Image.Image image mode=RGB size=910x607>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train2/weights/best.pt")

# Perform object detection on an image
results = model("/content/test", save=True)
results[0].show()
# Out:
# image 1/12 /content/test/0.jpg: 448x640 1 License_Plate, 23.8ms
# image 2/12 /content/test/1.jpg: 384x640 1 License_Plate, 19.1ms
# image 3/12 /content/test/10.jpg: 640x512 1 License_Plate, 74.3ms
# image 4/12 /content/test/11.jpg: 640x512 1 License_Plate, 16.0ms
# image 5/12 /content/test/12.jpg: 448x640 1 License_Plate, 14.8ms
# image 6/12 /content/test/2.jpg: 480x640 2 License_Plates, 72.3ms
# image 7/12 /content/test/3.jpg: 256x640 2 License_Plates, 78.6ms
# image 8/12 /content/test/5.jpg: 256x640 1 License_Plate, 14.6ms
# image 9/12 /content/test/6.jpg: 512x640 1 License_Plate, 71.8ms
# image 10/12 /content/test/7.jpg: 448x640 1 License_Plate, 14.1ms
# image 11/12 /content/test/8.jpg: 448x640 1 License_Plate, 12.7ms
# image 12/12 /content/test/9.jpg: 640x512 1 License_Plate, 17.7ms
# Speed: 3.6ms preprocess, 35.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/detect/predict4
# <PIL.Image.Image image mode=RGB size=910x607>

# %%
model = YOLO("runs/detect/train2/weights/best.pt")
results = model("/content/testvideo", save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/3 (frame 1/258) /content/testvideo/2.mp4: 384x640 1 License_Plate, 15.7ms
# video 1/3 (frame 2/258) /content/testvideo/2.mp4: 384x640 1 License_Plate, 16.9ms
# video 1/3 (frame 3/258) /content/testvideo/2.mp4: 384x640 1 License_Plate, 14.3ms
# video 1/3 (frame 4/258) /content/testvideo/2.mp4: 384x640 1 License_Plate, 15.4ms
# video 1/3 (frame 5/258) /content/testvideo/2.mp4: 384x640 1 License_Plate, 18.2ms
# ...

# %%
model = YOLO("runs/detect/train2/weights/best.pt")
results = model("/content/testvideo/Automatic Number Plate Recognition (ANPR) _ Vehicle Number Plate Recognition.mp4", save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/930) /content/testvideo/Automatic Number Plate Recognition (ANPR) _ Vehicle Number Plate Recognition.mp4: 384x640 (no detections), 100.9ms
# video 1/1 (frame 2/930) /content/testvideo/Automatic Number Plate Recognition (ANPR) _ Vehicle Number Plate Recognition.mp4: 384x640 (no detections), 9.3ms
# ...

# %%
13

# !zip -r /content/runs_data.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/results.png (deflated 7%)
#   adding: content/runs/detect/train2/confusion_matrix.png (deflated 34%)
#   adding: content/runs/detect/train2/R_curve.png (deflated 17%)
#   adding: content/runs/detect/train2/P_curve.png (deflated 19%)
#   adding: content/runs/detect/train2/val_batch1_labels.jpg (deflated 6%)
#   adding: content/runs/detect/train2/F1_curve.png (deflated 16%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/weights/last.pt (deflated 10%)
#   adding: content/runs/detect/train2/weights/best.pt (deflated 10%)
#   adding: content/runs/detect/train2/labels_correlogram.jpg (deflated 30%)
#   adding: content/runs/detect/train2/val_batch2_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train2/val_batch0_labels.jpg (deflated 6%)
# ...

# %%
# !zip -r /content/runs_dddddata.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict9/ (stored 0%)
#   adding: content/runs/detect/predict9/0019_JPEG.rf.8f6151c03872a14cef97f7c051cc815c.jpg (deflated 8%)
#   adding: content/runs/detect/predict9/0615_JPEG.rf.f2a3f4db82e263c7aeb079ffb876ad3e.jpg (deflated 4%)
#   adding: content/runs/detect/predict9/0672_JPEG.rf.a65f5eded3879205724b92f5602101a9.jpg (deflated 4%)
#   adding: content/runs/detect/predict9/0171_JPEG.rf.e28a616da1461185cf0c345e0a0a58c9.jpg (deflated 6%)
#   adding: content/runs/detect/predict9/0346_JPEG.rf.b93557c57835467e35b30be89dbe3094.jpg (deflated 5%)
#   adding: content/runs/detect/predict9/0472_JPEG.rf.a032b57fa4a4d7ffb9edbb87dbd79926.jpg (deflated 5%)
#   adding: content/runs/detect/predict9/0711_JPEG.rf.a008b492138dcca6014495b3afbb85bd.jpg (deflated 8%)
#   adding: content/runs/detect/predict9/0459_JPEG.rf.f58f4a66cdefec51423aa38ae6824a12.jpg (deflated 6%)
# ...
